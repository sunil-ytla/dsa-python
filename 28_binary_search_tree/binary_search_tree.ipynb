# %%
# Binary Search tree

from collections import deque

class BSTNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None



def insertNode(rootNode, nodeValue):
    if rootNode.data == None:
        rootNode.data = nodeValue
    elif nodeValue<=rootNode.data:
        if rootNode.left is None:
            rootNode.left = BSTNode(nodeValue)
        else:
            insertNode(rootNode.left, nodeValue)
    else:
        if rootNode.right is None:
            rootNode.right = BSTNode(nodeValue)
        else:
            insertNode(rootNode.right, nodeValue)
    
    return "node has been sucessfulley inserted"

def preOrderTraversal(rootNode):
    if not rootNode:
        return
    print(rootNode.data)
    preOrderTraversal(rootNode.left)
    preOrderTraversal(rootNode.right)

def inOrderTraversal(rootNode):
    if not rootNode:
        return
    inOrderTraversal(rootNode.left)
    print(rootNode.data)
    inOrderTraversal(rootNode.right)

def postOrderTraversal(rootNode):
    if not rootNode:
        return
    postOrderTraversal(rootNode.left)
    postOrderTraversal(rootNode.right)
    print(rootNode.data)

def levelOrderTraversal(rootNode):
    if not rootNode:
        return
    else:
        queue = deque()
        queue.append(rootNode)
        while queue:
            root = queue.popleft()
            print(root.data)
            if root.left:
                queue.append(root.left)
            if root.right:
                queue.append(root.right)
            
def searchBST(rootNode, data):
    if rootNode:
        if rootNode.data == data:
            print("found")
        elif rootNode.data < data:
            if rootNode.right:
                if rootNode.right.data == data:
                    print("found")
                else:
                    searchBST(rootNode.right, data)
        else:
            if rootNode.left:
                if rootNode.left.data == data:
                    print("found")
                else:
                    searchBST(rootNode.left, data)

def minValueNode(node):
    current = node
    while current.left is not None:
        current = current.left
    return current

def deleteNode(rootNode, nodeValue):
    if rootNode is None:
        return rootNode

    if nodeValue < rootNode.data:
        rootNode.left = deleteNode(rootNode.left, nodeValue)
    elif nodeValue > rootNode.data:
        rootNode.right = deleteNode(rootNode.right, nodeValue)
    else:
        # Case 1: Node has only one child or no child
        if rootNode.left is None:
            return rootNode.right
        elif rootNode.right is None:
            return rootNode.left

        # Case 2: Node has two children, find inorder successor
        minNode = minValueNode(rootNode.right)
        rootNode.data = minNode.data  # Copy the inorder successor's data
        rootNode.right = deleteNode(rootNode.right, minNode.data)  # Delete the inorder successor

    return rootNode  # Return the updated root

def deleteBST(rootNode):
    rootNode.data = None
    rootNode.left = None
    rootNode.right = None
    return 'bst deleted'

# %%
new_bst = BSTNode(None)
print(insertNode(new_bst, 70))
print(insertNode(new_bst, 50))
print(insertNode(new_bst, 90))
print(insertNode(new_bst, 30))
print(insertNode(new_bst, 60))
print(insertNode(new_bst, 80))
print(insertNode(new_bst, 100))
print(insertNode(new_bst, 20))
print(insertNode(new_bst, 40))
# Out:
# node has been sucessfulley inserted
# node has been sucessfulley inserted
# node has been sucessfulley inserted
# node has been sucessfulley inserted
# node has been sucessfulley inserted
# node has been sucessfulley inserted
# node has been sucessfulley inserted
# node has been sucessfulley inserted
# node has been sucessfulley inserted

# %%
preOrderTraversal(new_bst)
# Out:
# 70
# 50
# 30
# 20
# 40
# 60
# 90
# 80
# 100

# %%
inOrderTraversal(new_bst)
# Out:
# 20
# 30
# 40
# 50
# 60
# 70
# 80
# 90
# 100

# %%
postOrderTraversal(new_bst)
# Out:
# 20
# 40
# 30
# 60
# 50
# 80
# 100
# 90
# 70

# %%
levelOrderTraversal(new_bst)
# Out:
# 70
# 50
# 90
# 30
# 60
# 80
# 100
# 20
# 40

# %%
searchBST(new_bst, 110)

# %%
deleteNode(new_bst, 20)

# %%
levelOrderTraversal(new_bst)
# Out:
# 70
# 50
# 90
# 30
# 60
# 80
# 100
# 40

# %%
deleteBST(new_bst)
# Out:
# 'bst deleted'

# %% [markdown]
# ![image.png](attachment:image.png)
#
# https://www.udemy.com/course/data-structures-and-algorithms-bootcamp-in-python/learn/lecture/20878406#questions/19429154
