# %%
eng_sp = dict(one='uno', two='dos', three='tres')
print(eng_sp)
# Out:
# {'one': 'uno', 'two': 'dos', 'three': 'tres'}

# %%
eng_sp = dict([('one', 'uno'), ('two', 'dos'), ('three', 'tres')])
print(eng_sp)
# Out:
# {'one': 'uno', 'two': 'dos', 'three': 'tres'}

# %%
eng_sp = {'one': 'uno', 'two': 'dos', 'three': 'tres', 'four': 'cuatro'}
print(eng_sp)
# Out:
# {'one': 'uno', 'two': 'dos', 'three': 'tres', 'four': 'cuatro'}

# %%
# delete an item
del eng_sp['one']
print(eng_sp)
# Out:
# {'two': 'dos', 'three': 'tres', 'four': 'cuatro'}

# %%
del eng_sp['one']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 del eng_sp['one']
#
# KeyError: 'one'

# %%
# delete using pop
popped = eng_sp.pop('two')
print(popped, eng_sp)
# Out:
# dos {'three': 'tres', 'four': 'cuatro'}

# %%
# delete using pop
popped = eng_sp.pop('two')
print(popped, eng_sp)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 2
#       1 # delete using pop
# ----> 2 popped = eng_sp.pop('two')
#       3 print(popped, eng_sp)
#
# KeyError: 'two'

# %%
# delete using pop
popped = eng_sp.pop('two', None)
print(popped, eng_sp)
# Out:
# None {'three': 'tres'}

# %%
# delete using popitem , it will delete the last item
popped = eng_sp.popitem()
print(popped, eng_sp)
# Out:
# ('four', 'cuatro') {'three': 'tres'}

# %%
myDict = {'name': 'Jack', 'age': 26, 'address': 'Downtown'}
myDict.clear()
print(myDict)
# Out:
# {}

# %%
# shallow copy
eng_sp = {'one': 'uno', 'two': 'dos', 'three': 'tres'}
copy = eng_sp.copy()
print(copy)
# Out:
# {'one': 'uno', 'two': 'dos', 'three': 'tres'}

# %%
# using get
print(eng_sp.get('one'))
print(eng_sp.get('four'))
print(eng_sp.get('four', 'not found'))
# Out:
# uno
# None
# not found

# %%
# using items
print(eng_sp.items())
# Out:
# dict_items([('one', 'uno'), ('two', 'dos'), ('three', 'tres')])

# %%
# using items and loop
for k, v in eng_sp.items():
    print(k, v)
# Out:
# one uno
# two dos
# three tres

# %%
# using keys
print(eng_sp.keys())
# Out:
# dict_keys(['one', 'two', 'three'])

# %%
# using keys and loop
for k in eng_sp.keys():
    print(k)
# Out:
# one
# two
# three

# %%
# using values
print(eng_sp.values())
# Out:
# dict_values(['uno', 'dos', 'tres'])

# %%
# using values and loop
for v in eng_sp.values():
    print(v)
# Out:
# uno
# dos
# tres

# %%
# using update
eng_sp = {'one': 'uno', 'two': 'dos', 'three': 'tres', 'four': 4}
eng_sp.update({'four': 'cuatro', 'five': 'cinco'})
print(eng_sp)
# Out:
# {'one': 'uno', 'two': 'dos', 'three': 'tres', 'four': 'cuatro', 'five': 'cinco'}

# %%
# using in operator
print('one' in eng_sp)
print('six' in eng_sp)
print('one' not in eng_sp)
# Out:
# True
# False
# False

# %%
# using in with values
print('uno' in eng_sp.values())
print('seis' in eng_sp.values())
print('uno' not in eng_sp.values())
# Out:
# True
# False
# False

# %%
# using sorted
myDict = {1: 'apple', 4: 'ball', 2: 'cat', 6: 'dog', 3: 'elephant'}
print(sorted(myDict))
# Out:
# [1, 2, 3, 4, 6]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# dictionary comprehension
myDict = {x: x**2 for x in (2, 4, 6)}
print(myDict)
# Out:
# {2: 4, 4: 16, 6: 36}

# %%
# dictionary comprehension from another dictionary
myDict = {'a': 1, 'b': 2, 'c': 3}
myDict = {k: v*2 for k, v in myDict.items()}
print(myDict)
# Out:
# {'a': 2, 'b': 4, 'c': 6}

# %%
# dictionary comprehension with condition
myDict = {x: x**2 for x in (2, 4, 6) if x > 2}
print(myDict)
# Out:
# {4: 16, 6: 36}

# %%
# dictionary comprehension with condition
myDict = {'a': 1, 'b': 2, 'c': 3}
myDict = {k: v*2 for k, v in myDict.items() if v > 2}
print(myDict)
# Out:
# {'c': 6}

# %%
# dictionary comprehension with if else
myDict = {x: 'even' if x % 2 == 0 else 'odd' for x in range(1, 6)}
print(myDict)
# Out:
# {1: 'odd', 2: 'even', 3: 'odd', 4: 'even', 5: 'odd'}

# %% [markdown]
# Count Word Frequency
#
# Define a function to count the frequency of words in a given list of words.
#
# Example:
#
#     words = ['apple', 'orange', 'banana', 'apple', 'orange', 'apple']
#     count_word_frequency(words)
#
# Output:
#
#      {'apple': 3, 'orange': 2, 'banana': 1}

# %%
def count_word_frequency(words):
    frequency_dict = {}
    for i in words:
        if i in frequency_dict:
            frequency_dict[i]+=1
        else:
            frequency_dict[i]=1
    return frequency_dict

words = ['apple', 'orange', 'banana', 'apple', 'orange', 'apple'] 
count_word_frequency(words)
# Out:
# {'apple': 3, 'orange': 2, 'banana': 1}

# %% [markdown]
# Common Keys
#
# Define a function with takes two dictionaries as parameters and merge them and sum the values of common keys.
#
# Example:
#
#     dict1 = {'a': 1, 'b': 2, 'c': 3}
#     dict2 = {'b': 3, 'c': 4, 'd': 5}
#     merge_dicts(dict1, dict2)
#
# Output:
#
#     {'a': 1, 'b': 5, 'c': 7, 'd': 5}

# %%
def merge_dicts(dict1, dict2):
    for i, j in dict1.items():
        if i in dict2:
            dict2[i]+=dict1[i]
        else:
            dict2[i]=j
    return dict2

dict1 = {'a': 1, 'b': 2, 'c': 3}
dict2 = {'b': 3, 'c': 4, 'd': 5}
merge_dicts(dict1, dict2)
# Out:
# {'b': 5, 'c': 7, 'd': 5, 'a': 1}

# %% [markdown]
# Reverse Key-Value Pairs
#
# Define a function which takes as a parameter dictionary and returns a dictionary in which everse the key-value pairs are reversed.
#
# Example:
#
#     my_dict = {'a': 1, 'b': 2, 'c': 3}
#     reverse_dict(my_dict)
#
# Output:
#
#     {1: 'a', 2: 'b', 3: 'c'}

# %%
def reverse_dict(my_dict):
    return {v:k for k,v in my_dict.items()}


my_dict = {'a': 1, 'b': 2, 'c': 3}
reverse_dict(my_dict)
# Out:
# {1: 'a', 2: 'b', 3: 'c'}

# %% [markdown]
# Conditional Filter
#
# Define a function that takes a dictionary as a parameter and returns a dictionary with elements based on a condition.
#
# Example:
#
#     my_dict = {'a': 1, 'b': 2, 'c': 3, 'd': 4}
#     filtered_dict = filter_dict(my_dict, lambda k, v: v % 2 == 0)
#
# Output:
#
#     {'b': 2, 'd': 4}

# %%
def filter_dict(my_dict, condition):
    # TODO
    return {k:v for k,v in my_dict.items() if condition(k,v)}

my_dict = {'a': 1, 'b': 2, 'c': 3, 'd': 4} 
filtered_dict = filter_dict(my_dict, lambda k, v: v % 2 == 0) 
print(filtered_dict)
# Out:
# {'b': 2, 'd': 4}
